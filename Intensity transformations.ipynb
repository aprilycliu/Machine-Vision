# %%
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image

# %%
im = Image.open("mammogram.tif")
im.show()
imarray = np.array(im)

# %%
negative = 255 - imarray
Image.fromarray(negative)

# %%
im2 = Image.open("pollen.tif")
#im2.show()
imarray2 = np.array(im2)

# %%
plt.hist(imarray2.ravel(),256,[0,256])
plt.title("Grayscale Histogram")
plt.xlabel("grayscale value")
plt.ylabel("pixels")
plt.show()

# %%
equalized_img = cv2.equalizeHist(imarray2)

# %%
plt.hist(equalized_img.ravel(),256,[0,256])
plt.title("Grayscale Histogram")
plt.xlabel("grayscale value")
plt.ylabel("pixels")
plt.show()

# %%
def display(img):
    im = Image.open(img)
    imarray = np.array(im)
    equalized_img = cv2.equalizeHist(imarray)
    
    f, ax = plt.subplots(1, 2)
    plt.suptitle("Histogram Equalization")
    ax[0].imshow(im, 'gray')
    ax[1].imshow(equalized_img, 'gray')
    
    plt.show()

# %%
display("pollen.tif")
