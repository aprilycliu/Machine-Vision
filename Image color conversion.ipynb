# %%
from matplotlib import pyplot as plt
from PIL import Image
import numpy as np
import colorsys

# %%
color_im = Image.open("4.2.03.tif")
color_array = np.array(color_im)
color_array.shape
# Out:
# (512, 512, 3)

# %%
def rgb_to_hsv(img):
    if isinstance(img,Image.Image):
        r,g,b = img.split()
        Hdat = []
        Sdat = []
        Vdat = [] 
        for rd,gn,bl in zip(r.getdata(),g.getdata(),b.getdata()) :
            h,s,v = colorsys.rgb_to_hsv(rd/255.,gn/255.,bl/255.)
            Hdat.append(int(h*255.))
            Sdat.append(int(s*255.))
            Vdat.append(int(v*255.))
        r.putdata(Hdat)
        g.putdata(Sdat)
        b.putdata(Vdat)
        return Image.merge('RGB',(r,g,b))

# %%
rgb_to_hsv(color_im)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x122AFD940>

# %%
def rgb_to_yiq(img):
    if isinstance(img,Image.Image):
        r,g,b = img.split()
        Hdat = []
        Sdat = []
        Vdat = [] 
        for rd,gn,bl in zip(r.getdata(),g.getdata(),b.getdata()) :
            h,s,v = colorsys.rgb_to_yiq(rd/255.,gn/255.,bl/255.)
            Hdat.append(int(h*255.))
            Sdat.append(int(s*255.))
            Vdat.append(int(v*255.))
        r.putdata(Hdat)
        g.putdata(Sdat)
        b.putdata(Vdat)
        return Image.merge('RGB',(r,g,b))

# %%
rgb_to_yiq(color_im )
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x122AF1C88>
